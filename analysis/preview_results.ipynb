# %% [markdown]
# # nnU-Net Results Preview for ARCADE
#
# Preview nnU-Net framework predictions for ARCADE using class-ID masks. The notebook can optionally run inference from a checkpoint first, then visualize raw image, ground truth, prediction, confusion overlays, and calculate pixel and boundary metrics.

# %%
# Imports and paths
from __future__ import annotations

import os
import re
import shutil
import subprocess
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
from PIL import Image

try:
    import cv2
except Exception:
    cv2 = None

try:
    from skimage.morphology import skeletonize
except Exception:
    skeletonize = None


def _find_repo_root(start: Path) -> Path:
    """Walk up from cwd looking for the repo root, so this notebook works the
    same whether Jupyter's cwd is the repo root or analysis/ itself."""
    for candidate in [start, *start.parents]:
        if (candidate / "lightm-unet").exists() and (candidate / "data").exists():
            return candidate
    return start

REPO_ROOT = _find_repo_root(Path.cwd())
if (REPO_ROOT / "lightm-unet").exists():
    PACKAGE_ROOT = REPO_ROOT / "lightm-unet"
else:
    PACKAGE_ROOT = REPO_ROOT

# Shared loading/topology helpers live in analysis/segmentation_topology.py --
# imported once here so every later cell (and shape_diagnostics.py, and
# compute_topology_metrics.py) uses the same case-ID/mask-loading conventions
# instead of each redefining them.
sys.path.insert(0, str(REPO_ROOT / "analysis"))
import segmentation_topology as topo

METRICS_DIR = REPO_ROOT / "analysis" / "results"
METRICS_DIR.mkdir(parents=True, exist_ok=True)

DATASET_NAME = "Dataset501_ARCADE"
DATASET_ID = "501"
CONFIGURATION = "2d"
PLANS_NAME = "nnUNetPlans"
FOLD = 0

DATASET_DIR = REPO_ROOT / "data" / "nnUNet_raw" / DATASET_NAME
IMAGES_TS_DIR = DATASET_DIR / "imagesTs"
LABELS_TS_DIR = DATASET_DIR / "labelsTs"
NNUNET_PREPROCESSED = REPO_ROOT / "data" / "nnUNet_preprocessed"
NNUNET_RESULTS = REPO_ROOT / "data" / "nnUNET_results"

NET_NAME = "ENetGlobalCtxG3"
TRAINER_NAME = "nnUNetTrainerENetGlobalCtx"
CHECKPOINT_PATH = NNUNET_RESULTS / DATASET_NAME / f"{TRAINER_NAME}__{PLANS_NAME}__{CONFIGURATION}" / f"fold_{FOLD}" / "checkpoint_best.pth"
CHECKPOINT_NAME = CHECKPOINT_PATH.name
PREDICTION_DIR = DATASET_DIR / f"labelsPr_{NET_NAME}"
LEGACY_PREDICTED_DIR = DATASET_DIR / "predicted"

N_CLASSES = 4
CLASS_LABELS = ["Background", "LAD", "RCA", "LCX"]
CLASS_COLORS = ["#000000", "#e6194b", "#3cb44b", "#4363d8"]
CMAP = mcolors.ListedColormap(CLASS_COLORS)
NORM = mcolors.BoundaryNorm(range(N_CLASSES + 1), N_CLASSES)
IMSHOW_MASK_KW = dict(cmap=CMAP, norm=NORM, interpolation="nearest")
IMG_EXTS = topo.IMG_EXTS

print("Repo root       :", REPO_ROOT)
print("Package root    :", PACKAGE_ROOT)
print("Dataset dir     :", DATASET_DIR)
print("ImagesTs        :", IMAGES_TS_DIR)
print("LabelsTs        :", LABELS_TS_DIR)
print("Prediction dir  :", PREDICTION_DIR)
print("Checkpoint      :", CHECKPOINT_PATH)

# %% [markdown]
# ## Optional: Run Inference From a Checkpoint
#
# This cell runs nnU-Net inference on `imagesTs` and writes class-ID predictions to `labelsPr_[NETNAME]`. It also adopts an existing `predicted/` directory by renaming it to `labelsPr_[NETNAME]` when appropriate.

# %%
# Inference block
RUN_INFERENCE = False          # Set True to generate predictions from CHECKPOINT_PATH
OVERWRITE_PREDICTIONS = False  # Set True to replace existing labelsPr_[NETNAME]
DEVICE = "cuda"               # "cuda" or "cpu"
DISABLE_TTA = True             # Faster previews; set False for nnU-Net default mirroring TTA
NUM_PREPROCESS_WORKERS = 2
NUM_EXPORT_WORKERS = 2


def adopt_legacy_predicted_folder() -> None:
    if not LEGACY_PREDICTED_DIR.exists():
        return
    legacy_files = [p for p in LEGACY_PREDICTED_DIR.iterdir() if p.is_file() and p.suffix.lower() in IMG_EXTS]
    if not legacy_files:
        print(f"Legacy folder exists but has no prediction masks: {LEGACY_PREDICTED_DIR}")
        return
    if not PREDICTION_DIR.exists():
        LEGACY_PREDICTED_DIR.rename(PREDICTION_DIR)
        print(f"Renamed {LEGACY_PREDICTED_DIR} -> {PREDICTION_DIR}")
    else:
        print(f"Keeping {PREDICTION_DIR}; legacy folder also exists at {LEGACY_PREDICTED_DIR}")


def infer_trainer_from_checkpoint(checkpoint: Path) -> str:
    model_folder = checkpoint.parents[1]
    return model_folder.name.split("__", 1)[0] if "__" in model_folder.name else TRAINER_NAME


def run_nnunet_inference() -> None:
    if not CHECKPOINT_PATH.exists():
        raise FileNotFoundError(f"Checkpoint not found: {CHECKPOINT_PATH}")
    if not IMAGES_TS_DIR.exists():
        raise FileNotFoundError(f"imagesTs not found: {IMAGES_TS_DIR}")

    if PREDICTION_DIR.exists() and OVERWRITE_PREDICTIONS:
        shutil.rmtree(PREDICTION_DIR)
    PREDICTION_DIR.mkdir(parents=True, exist_ok=True)

    trainer = infer_trainer_from_checkpoint(CHECKPOINT_PATH)
    os.environ["nnUNet_raw"] = str(REPO_ROOT / "data" / "nnUNet_raw")
    os.environ["nnUNet_preprocessed"] = str(NNUNET_PREPROCESSED)
    os.environ["nnUNet_results"] = str(NNUNET_RESULTS)

    command = [
        shutil.which("nnUNetv2_predict") or "nnUNetv2_predict",
        "-i", str(IMAGES_TS_DIR),
        "-o", str(PREDICTION_DIR),
        "-d", DATASET_ID,
        "-c", CONFIGURATION,
        "-tr", trainer,
        "-p", PLANS_NAME,
        "-f", str(FOLD),
        "-chk", CHECKPOINT_NAME,
        "-device", DEVICE,
        "-npp", str(NUM_PREPROCESS_WORKERS),
        "-nps", str(NUM_EXPORT_WORKERS),
        "--disable_progress_bar",
    ]
    if DISABLE_TTA:
        command.append("--disable_tta")

    print("Running:", " ".join(command))
    completed = subprocess.run(command, cwd=PACKAGE_ROOT, text=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    print(completed.stdout)
    if completed.returncode != 0:
        raise RuntimeError(f"nnU-Net inference failed with return code {completed.returncode}")

adopt_legacy_predicted_folder()
if RUN_INFERENCE:
    run_nnunet_inference()
else:
    print("RUN_INFERENCE=False; using existing predictions if present.")
# Out:
# Legacy folder exists but has no prediction masks: /workspace/LightM-UNet/data/nnUNet_raw/Dataset501_ARCADE/predicted
# Running: /opt/conda/bin/nnUNetv2_predict -i /workspace/LightM-UNet/data/nnUNet_raw/Dataset501_ARCADE/imagesTs -o /workspace/LightM-UNet/data/nnUNet_raw/Dataset501_ARCADE/labelsPr_ENetComboE1-2 -d 501 -c 2d -tr nnUNetTrainerENetOriginal -p nnUNetPlans -f 0 -chk checkpoint_best.pth -device cuda -npp 2 -nps 2 --disable_progress_bar --disable_tta
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# /opt/conda/lib/python3.10/site-packages/monai/utils/module.py:396: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   pkg = __import__(module)  # top level module
# There are 300 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 300 cases that I would like to predict
#
# Predicting test_1:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_1
#
# Predicting test_10:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_10
#
# Predicting test_100:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_100
#
# Predicting test_101:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_101
#
# Predicting test_102:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_102
#
# Predicting test_103:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_103
#
# Predicting test_104:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_104
#
# Predicting test_105:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_105
#
# Predicting test_106:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_106
#
# Predicting test_107:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_107
#
# Predicting test_108:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_108
#
# Predicting test_109:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_109
#
# Predicting test_11:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_11
#
# Predicting test_110:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_110
#
# Predicting test_111:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_111
#
# Predicting test_112:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_112
#
# Predicting test_113:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_113
#
# Predicting test_114:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_114
#
# Predicting test_115:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_115
#
# Predicting test_116:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_116
#
# Predicting test_117:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_117
#
# Predicting test_118:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_118
#
# Predicting test_119:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_119
#
# Predicting test_12:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_12
#
# Predicting test_120:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_120
#
# Predicting test_121:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_121
#
# Predicting test_122:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_122
#
# Predicting test_123:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_123
#
# Predicting test_124:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_124
#
# Predicting test_125:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_125
#
# Predicting test_126:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_126
#
# Predicting test_127:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_127
#
# Predicting test_128:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_128
#
# Predicting test_129:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_129
#
# Predicting test_13:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_13
#
# Predicting test_130:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_130
#
# Predicting test_131:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_131
#
# Predicting test_132:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_132
#
# Predicting test_133:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_133
#
# Predicting test_134:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_134
#
# Predicting test_135:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_135
#
# Predicting test_136:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_136
#
# Predicting test_137:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_137
#
# Predicting test_138:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_138
#
# Predicting test_139:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_139
#
# Predicting test_14:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_14
#
# Predicting test_140:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_140
#
# Predicting test_141:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_141
#
# Predicting test_142:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_142
#
# Predicting test_143:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_143
#
# Predicting test_144:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_144
#
# Predicting test_145:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_145
#
# Predicting test_146:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_146
#
# Predicting test_147:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_147
#
# Predicting test_148:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_148
#
# Predicting test_149:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_149
#
# Predicting test_15:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_15
#
# Predicting test_150:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_150
#
# Predicting test_151:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_151
#
# Predicting test_152:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_152
#
# Predicting test_153:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_153
#
# Predicting test_154:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_154
#
# Predicting test_155:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_155
#
# Predicting test_156:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_156
#
# Predicting test_157:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_157
#
# Predicting test_158:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_158
#
# Predicting test_159:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_159
#
# Predicting test_16:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_16
#
# Predicting test_160:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_160
#
# Predicting test_161:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_161
#
# Predicting test_162:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_162
#
# Predicting test_163:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_163
#
# Predicting test_164:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_164
#
# Predicting test_165:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_165
#
# Predicting test_166:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_166
#
# Predicting test_167:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_167
#
# Predicting test_168:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_168
#
# Predicting test_169:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_169
#
# Predicting test_17:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_17
#
# Predicting test_170:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_170
#
# Predicting test_171:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_171
#
# Predicting test_172:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_172
#
# Predicting test_173:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_173
#
# Predicting test_174:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_174
#
# Predicting test_175:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_175
#
# Predicting test_176:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_176
#
# Predicting test_177:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_177
#
# Predicting test_178:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_178
#
# Predicting test_179:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_179
#
# Predicting test_18:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_18
#
# Predicting test_180:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_180
#
# Predicting test_181:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_181
#
# Predicting test_182:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_182
#
# Predicting test_183:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_183
#
# Predicting test_184:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_184
#
# Predicting test_185:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_185
#
# Predicting test_186:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_186
#
# Predicting test_187:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_187
#
# Predicting test_188:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_188
#
# Predicting test_189:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_189
#
# Predicting test_19:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_19
#
# Predicting test_190:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_190
#
# Predicting test_191:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_191
#
# Predicting test_192:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_192
#
# Predicting test_193:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_193
#
# Predicting test_194:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_194
#
# Predicting test_195:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_195
#
# Predicting test_196:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_196
#
# Predicting test_197:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_197
#
# Predicting test_198:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_198
#
# Predicting test_199:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_199
#
# Predicting test_2:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_2
#
# Predicting test_20:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_20
#
# Predicting test_200:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_200
#
# Predicting test_201:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_201
#
# Predicting test_202:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_202
#
# Predicting test_203:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_203
#
# Predicting test_204:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_204
#
# Predicting test_205:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_205
#
# Predicting test_206:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_206
#
# Predicting test_207:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_207
#
# Predicting test_208:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_208
#
# Predicting test_209:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_209
#
# Predicting test_21:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_21
#
# Predicting test_210:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_210
#
# Predicting test_211:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_211
#
# Predicting test_212:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_212
#
# Predicting test_213:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_213
#
# Predicting test_214:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_214
#
# Predicting test_215:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_215
#
# Predicting test_216:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_216
#
# Predicting test_217:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_217
#
# Predicting test_218:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_218
#
# Predicting test_219:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_219
#
# Predicting test_22:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_22
#
# Predicting test_220:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_220
#
# Predicting test_221:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_221
#
# Predicting test_222:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_222
#
# Predicting test_223:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_223
#
# Predicting test_224:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_224
#
# Predicting test_225:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_225
#
# Predicting test_226:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_226
#
# Predicting test_227:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_227
#
# Predicting test_228:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_228
#
# Predicting test_229:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_229
#
# Predicting test_23:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_23
#
# Predicting test_230:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_230
#
# Predicting test_231:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_231
#
# Predicting test_232:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_232
#
# Predicting test_233:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_233
#
# Predicting test_234:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_234
#
# Predicting test_235:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_235
#
# Predicting test_236:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_236
#
# Predicting test_237:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_237
#
# Predicting test_238:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_238
#
# Predicting test_239:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_239
#
# Predicting test_24:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_24
#
# Predicting test_240:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_240
#
# Predicting test_241:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_241
#
# Predicting test_242:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_242
#
# Predicting test_243:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_243
#
# Predicting test_244:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_244
#
# Predicting test_245:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_245
#
# Predicting test_246:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_246
#
# Predicting test_247:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_247
#
# Predicting test_248:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_248
#
# Predicting test_249:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_249
#
# Predicting test_25:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_25
#
# Predicting test_250:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_250
#
# Predicting test_251:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_251
#
# Predicting test_252:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_252
#
# Predicting test_253:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_253
#
# Predicting test_254:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_254
#
# Predicting test_255:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_255
#
# Predicting test_256:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_256
#
# Predicting test_257:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_257
#
# Predicting test_258:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_258
#
# Predicting test_259:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_259
#
# Predicting test_26:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_26
#
# Predicting test_260:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_260
#
# Predicting test_261:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_261
#
# Predicting test_262:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_262
#
# Predicting test_263:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_263
#
# Predicting test_264:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_264
#
# Predicting test_265:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_265
#
# Predicting test_266:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_266
#
# Predicting test_267:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_267
#
# Predicting test_268:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_268
#
# Predicting test_269:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_269
#
# Predicting test_27:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_27
#
# Predicting test_270:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_270
#
# Predicting test_271:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_271
#
# Predicting test_272:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_272
#
# Predicting test_273:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_273
#
# Predicting test_274:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_274
#
# Predicting test_275:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_275
#
# Predicting test_276:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_276
#
# Predicting test_277:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_277
#
# Predicting test_278:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_278
#
# Predicting test_279:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_279
#
# Predicting test_28:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_28
#
# Predicting test_280:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_280
#
# Predicting test_281:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_281
#
# Predicting test_282:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_282
#
# Predicting test_283:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_283
#
# Predicting test_284:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_284
#
# Predicting test_285:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_285
#
# Predicting test_286:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_286
#
# Predicting test_287:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_287
#
# Predicting test_288:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_288
#
# Predicting test_289:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_289
#
# Predicting test_29:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_29
#
# Predicting test_290:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_290
#
# Predicting test_291:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_291
#
# Predicting test_292:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_292
#
# Predicting test_293:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_293
#
# Predicting test_294:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_294
#
# Predicting test_295:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_295
#
# Predicting test_296:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_296
#
# Predicting test_297:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_297
#
# Predicting test_298:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_298
#
# Predicting test_299:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_299
#
# Predicting test_3:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_3
#
# Predicting test_30:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_30
#
# Predicting test_300:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_300
#
# Predicting test_31:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_31
#
# Predicting test_32:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_32
#
# Predicting test_33:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_33
#
# Predicting test_34:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_34
#
# Predicting test_35:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_35
#
# Predicting test_36:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_36
#
# Predicting test_37:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_37
#
# Predicting test_38:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_38
#
# Predicting test_39:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_39
#
# Predicting test_4:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_4
#
# Predicting test_40:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_40
#
# Predicting test_41:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_41
#
# Predicting test_42:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_42
#
# Predicting test_43:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_43
#
# Predicting test_44:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_44
#
# Predicting test_45:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_45
#
# Predicting test_46:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_46
#
# Predicting test_47:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_47
#
# Predicting test_48:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_48
#
# Predicting test_49:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_49
#
# Predicting test_5:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_5
#
# Predicting test_50:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_50
#
# Predicting test_51:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_51
#
# Predicting test_52:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_52
#
# Predicting test_53:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_53
#
# Predicting test_54:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_54
#
# Predicting test_55:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_55
#
# Predicting test_56:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_56
#
# Predicting test_57:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_57
#
# Predicting test_58:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_58
#
# Predicting test_59:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_59
#
# Predicting test_6:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_6
#
# Predicting test_60:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_60
#
# Predicting test_61:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_61
#
# Predicting test_62:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_62
#
# Predicting test_63:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_63
#
# Predicting test_64:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_64
#
# Predicting test_65:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_65
#
# Predicting test_66:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_66
#
# Predicting test_67:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_67
#
# Predicting test_68:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_68
#
# Predicting test_69:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_69
#
# Predicting test_7:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_7
#
# Predicting test_70:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_70
#
# Predicting test_71:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_71
#
# Predicting test_72:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_72
#
# Predicting test_73:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_73
#
# Predicting test_74:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_74
#
# Predicting test_75:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_75
#
# Predicting test_76:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_76
#
# Predicting test_77:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_77
#
# Predicting test_78:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_78
#
# Predicting test_79:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_79
#
# Predicting test_8:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_8
#
# Predicting test_80:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_80
#
# Predicting test_81:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_81
#
# Predicting test_82:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_82
#
# Predicting test_83:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_83
#
# Predicting test_84:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_84
#
# Predicting test_85:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_85
#
# Predicting test_86:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_86
#
# Predicting test_87:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_87
#
# Predicting test_88:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_88
#
# Predicting test_89:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_89
#
# Predicting test_9:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_9
#
# Predicting test_90:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_90
#
# Predicting test_91:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_91
#
# Predicting test_92:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_92
#
# Predicting test_93:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_93
#
# Predicting test_94:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_94
#
# Predicting test_95:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_95
#
# Predicting test_96:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_96
#
# Predicting test_97:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_97
#
# Predicting test_98:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_98
#
# Predicting test_99:
# perform_everything_on_device: True
# sending off prediction to background worker for resampling and export
# done with test_99

# %% [markdown]
# ## Build Sample Index

# %%
# Match imagesTs, labelsTs, and labelsPr_[NETNAME] by case ID.
img_files = topo.image_files(IMAGES_TS_DIR)
gt_files = {p.stem: p for p in topo.image_files(LABELS_TS_DIR)}
pred_files = {p.stem: p for p in topo.image_files(PREDICTION_DIR)} if PREDICTION_DIR.exists() else {}

samples = []
for img in img_files:
    cid = topo.case_id_from_image(img)
    if cid in gt_files and cid in pred_files:
        samples.append({"case_id": cid, "image": img, "gt": gt_files[cid], "pred": pred_files[cid]})

print(f"ImagesTs found  : {len(img_files)}")
print(f"LabelsTs found  : {len(gt_files)}")
print(f"Predictions found: {len(pred_files)}")
print(f"Matched samples : {len(samples)}")

if not samples:
    raise FileNotFoundError(
        "No matched samples found. Run inference first or check PREDICTION_DIR.\n"
        f"ImagesTs: {IMAGES_TS_DIR}\nLabelsTs: {LABELS_TS_DIR}\nPredictions: {PREDICTION_DIR}"
    )

# %% [markdown]
# ## Loading Helpers

# %%
def load_sample(idx: int):
    item = samples[idx]
    raw = np.asarray(Image.open(item["image"]).convert("L"), dtype=np.float32) / 255.0
    gt = topo.load_class_id_mask(item["gt"])
    pred = topo.load_class_id_mask(item["pred"])
    pred = topo.resize_mask_to(pred, gt.shape)
    raw_display = raw
    if raw_display.shape != gt.shape:
        raw_display = np.asarray(Image.fromarray((raw_display * 255).astype(np.uint8)).resize((gt.shape[1], gt.shape[0]), Image.BICUBIC), dtype=np.float32) / 255.0
    return raw_display, gt, pred


def legend_handles():
    return [mpatches.Patch(color=CLASS_COLORS[i], label=f"{i}: {CLASS_LABELS[i]}") for i in range(N_CLASSES)]

# %% [markdown]
# ## Preview: Raw Image, Ground Truth, Prediction

# %%
def show_sample(idx: int, ax_row=None, save_path: Path | None = None):
    raw, gt, pred = load_sample(idx)
    standalone = ax_row is None
    if standalone:
        fig, axes = plt.subplots(1, 3, figsize=(14, 5))
    else:
        axes = ax_row
        fig = axes[0].figure

    axes[0].imshow(raw, cmap="gray")
    axes[0].set_title("Raw")
    axes[0].axis("off")

    axes[1].imshow(gt, **IMSHOW_MASK_KW)
    axes[1].set_title("Ground truth")
    axes[1].axis("off")

    axes[2].imshow(pred, **IMSHOW_MASK_KW)
    axes[2].set_title("Prediction")
    axes[2].axis("off")

    if standalone:
        fig.legend(handles=legend_handles(), loc="lower center", ncol=N_CLASSES, bbox_to_anchor=(0.5, -0.04), frameon=False)
        fig.suptitle(f"{idx}: {samples[idx]['case_id']}", fontsize=13, fontweight="bold")
        plt.tight_layout()
        if save_path:
            fig.savefig(save_path, bbox_inches="tight", dpi=150)
        plt.show()


def show_batch(indices=None, n_samples: int = 6, save_path: Path | None = None):
    if indices is None:
        indices = list(range(min(n_samples, len(samples))))
    indices = list(indices)
    fig, axes = plt.subplots(len(indices), 3, figsize=(14, 4.2 * len(indices)))
    axes = np.atleast_2d(axes)
    for row, idx in enumerate(indices):
        show_sample(idx, ax_row=axes[row])
        axes[row][0].set_ylabel(samples[idx]["case_id"], fontsize=9, rotation=90, labelpad=8)
    fig.legend(handles=legend_handles(), loc="lower center", ncol=N_CLASSES, bbox_to_anchor=(0.5, -0.01), frameon=False)
    plt.tight_layout()
    if save_path:
        fig.savefig(save_path, bbox_inches="tight", dpi=150)
    plt.show()

# show_batch(n_samples=50)

# %% [markdown]
# ## Confusion Overlay

# %%
CONFUSION_COLORS = {
    "TP": np.array([0, 200, 0, 210], dtype=np.uint8),
    "FP": np.array([220, 0, 0, 200], dtype=np.uint8),
    "FN": np.array([255, 190, 0, 210], dtype=np.uint8),
    "TN": np.array([0, 0, 0, 0], dtype=np.uint8),
}


def make_foreground_confusion(gt: np.ndarray, pred: np.ndarray) -> np.ndarray:
    gt_fg = gt > 0
    pred_fg = pred > 0
    overlay = np.zeros((*gt.shape, 4), dtype=np.uint8)
    overlay[(gt_fg & pred_fg)] = CONFUSION_COLORS["TP"]
    overlay[(~gt_fg & pred_fg)] = CONFUSION_COLORS["FP"]
    overlay[(gt_fg & ~pred_fg)] = CONFUSION_COLORS["FN"]
    return overlay


def show_confusion(idx: int, save_path: Path | None = None):
    raw, gt, pred = load_sample(idx)
    overlay = make_foreground_confusion(gt, pred)
    fig, axes = plt.subplots(1, 4, figsize=(18, 5))
    axes[0].imshow(raw, cmap="gray"); axes[0].set_title("Raw"); axes[0].axis("off")
    axes[1].imshow(gt, **IMSHOW_MASK_KW); axes[1].set_title("Ground truth"); axes[1].axis("off")
    axes[2].imshow(pred, **IMSHOW_MASK_KW); axes[2].set_title("Prediction"); axes[2].axis("off")
    axes[3].imshow(raw, cmap="gray"); axes[3].imshow(overlay); axes[3].set_title("Foreground confusion"); axes[3].axis("off")
    handles = [
        mpatches.Patch(color=CONFUSION_COLORS["TP"] / 255, label="TP"),
        mpatches.Patch(color=CONFUSION_COLORS["FP"] / 255, label="FP"),
        mpatches.Patch(color=CONFUSION_COLORS["FN"] / 255, label="FN"),
    ]
    fig.legend(handles=handles, loc="lower center", ncol=3, bbox_to_anchor=(0.5, -0.04), frameon=False)
    fig.suptitle(f"{idx}: {samples[idx]['case_id']}", fontsize=13, fontweight="bold")
    plt.tight_layout()
    if save_path:
        fig.savefig(save_path, bbox_inches="tight", dpi=150)
    plt.show()

show_confusion(0)

# %%
# Batch confusion grid
# from matplotlib import patches as mpatches

CONFUSION_LEGEND = [
    mpatches.Patch(color=CONFUSION_COLORS["TP"] / 255, label="TP: predicted vessel overlaps GT vessel"),
    mpatches.Patch(color=CONFUSION_COLORS["FP"] / 255, label="FP: predicted vessel on background"),
    mpatches.Patch(color=CONFUSION_COLORS["FN"] / 255, label="FN: missed GT vessel"),
]


def _confusion_grid(indices, save_path: Path | None = None):
    """Render raw image, GT, prediction, and foreground confusion for sample indices."""
    indices = list(indices)
    if not indices:
        print("No samples to display.")
        return

    fig, axes = plt.subplots(len(indices), 4, figsize=(18, 4.5 * len(indices)))
    axes = np.atleast_2d(axes)

    for col, title in enumerate(["Raw", "Ground truth", "Prediction", "Foreground confusion"]):
        axes[0, col].set_title(title, fontsize=11, fontweight="bold")

    for row, idx in enumerate(indices):
        raw, gt, pred = load_sample(idx)
        confusion = make_foreground_confusion(gt, pred)
        case_id = samples[idx]["case_id"]

        axes[row, 0].imshow(raw, cmap="gray")
        axes[row, 0].set_ylabel(f"#{idx}\n{case_id}", fontsize=8, rotation=0, labelpad=34, va="center")
        axes[row, 0].axis("off")

        axes[row, 1].imshow(gt, **IMSHOW_MASK_KW)
        axes[row, 1].axis("off")

        axes[row, 2].imshow(pred, **IMSHOW_MASK_KW)
        axes[row, 2].axis("off")

        axes[row, 3].imshow(raw, cmap="gray")
        axes[row, 3].imshow(confusion)
        axes[row, 3].axis("off")

    fig.legend(handles=CONFUSION_LEGEND, loc="lower center", ncol=3, bbox_to_anchor=(0.5, -0.01), frameon=False)
    plt.tight_layout(rect=[0, 0.04, 1, 1])
    if save_path:
        fig.savefig(save_path, bbox_inches="tight", dpi=150)
        print(f"Saved: {save_path}")
    plt.show()


def show_confusion_batch(n_samples: int = 6, save_path: Path | None = None):
    """Show the first n_samples matched test cases."""
    n_samples = min(n_samples, len(samples))
    _confusion_grid(range(n_samples), save_path=save_path)


def show_confusion_indices(indices, save_path: Path | None = None):
    """Show specific sample indices, for example [0, 12, 25]."""
    _confusion_grid(indices, save_path=save_path)

show_confusion_indices([i for i in range(0, 50)], save_path=METRICS_DIR / f"{NET_NAME}_confusion_grid_display.png")

# %% [markdown]
# ## Metrics: Dice/F1, Precision, Recall/Sensitivity, Boundary F1, clDice

# %%
EPS = 1e-8


def binary_counts(gt_bool: np.ndarray, pred_bool: np.ndarray) -> tuple[int, int, int]:
    tp = int((gt_bool & pred_bool).sum())
    fp = int((~gt_bool & pred_bool).sum())
    fn = int((gt_bool & ~pred_bool).sum())
    return tp, fp, fn


def prf_from_counts(tp: int, fp: int, fn: int) -> dict[str, float]:
    precision = tp / (tp + fp + EPS)
    recall = tp / (tp + fn + EPS)
    dice = (2 * tp) / (2 * tp + fp + fn + EPS)
    return {"dice_f1": dice, "precision": precision, "recall_sensitivity": recall}


def mask_boundary(mask: np.ndarray) -> np.ndarray:
    mask = mask.astype(bool)
    if cv2 is not None:
        kernel = np.ones((3, 3), dtype=np.uint8)
        eroded = cv2.erode(mask.astype(np.uint8), kernel, iterations=1).astype(bool)
        return mask & ~eroded
    padded = np.pad(mask, 1, mode="constant", constant_values=False)
    neighbors_all = np.ones_like(mask, dtype=bool)
    for dy in (-1, 0, 1):
        for dx in (-1, 0, 1):
            neighbors_all &= padded[1 + dy:1 + dy + mask.shape[0], 1 + dx:1 + dx + mask.shape[1]]
    return mask & ~neighbors_all


def dilate_binary(mask: np.ndarray, radius: int) -> np.ndarray:
    mask = mask.astype(bool)
    if radius <= 0:
        return mask
    if cv2 is not None:
        kernel = np.ones((2 * radius + 1, 2 * radius + 1), dtype=np.uint8)
        return cv2.dilate(mask.astype(np.uint8), kernel, iterations=1).astype(bool)
    out = mask.copy()
    padded = np.pad(mask, radius, mode="constant", constant_values=False)
    for dy in range(-radius, radius + 1):
        for dx in range(-radius, radius + 1):
            out |= padded[radius + dy:radius + dy + mask.shape[0], radius + dx:radius + dx + mask.shape[1]]
    return out


def binary_skeleton(mask: np.ndarray) -> np.ndarray:
    mask = mask.astype(bool)
    if not mask.any():
        return mask
    if skeletonize is not None:
        return skeletonize(mask).astype(bool)

    # Morphological skeleton fallback for environments without scikit-image.
    if cv2 is not None:
        work = mask.astype(np.uint8)
        skel = np.zeros_like(work, dtype=np.uint8)
        kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (3, 3))
        while work.any():
            eroded = cv2.erode(work, kernel)
            opened = cv2.dilate(eroded, kernel)
            skel |= work & ~opened
            work = eroded
        return skel.astype(bool)

    return mask_boundary(mask)


def cldice_components(gt_bool: np.ndarray, pred_bool: np.ndarray) -> tuple[int, int, int, int]:
    gt_bool = gt_bool.astype(bool)
    pred_bool = pred_bool.astype(bool)
    gt_skeleton = binary_skeleton(gt_bool)
    pred_skeleton = binary_skeleton(pred_bool)
    pred_skeleton_sum = int(pred_skeleton.sum())
    gt_skeleton_sum = int(gt_skeleton.sum())
    pred_skeleton_hits = int((pred_skeleton & gt_bool).sum())
    gt_skeleton_hits = int((gt_skeleton & pred_bool).sum())
    return pred_skeleton_hits, pred_skeleton_sum, gt_skeleton_hits, gt_skeleton_sum


def cldice_from_components(
    pred_skeleton_hits: int,
    pred_skeleton_sum: int,
    gt_skeleton_hits: int,
    gt_skeleton_sum: int,
) -> float:
    if pred_skeleton_sum == 0 and gt_skeleton_sum == 0:
        return 1.0
    if pred_skeleton_sum == 0 or gt_skeleton_sum == 0:
        return 0.0
    tprec = pred_skeleton_hits / (pred_skeleton_sum + EPS)
    tsens = gt_skeleton_hits / (gt_skeleton_sum + EPS)
    return float((2 * tprec * tsens) / (tprec + tsens + EPS))


def cldice_score(gt_bool: np.ndarray, pred_bool: np.ndarray) -> float:
    return cldice_from_components(*cldice_components(gt_bool, pred_bool))


def boundary_f1(gt_bool: np.ndarray, pred_bool: np.ndarray, tolerance_px: int = 2) -> float:
    gt_b = mask_boundary(gt_bool)
    pred_b = mask_boundary(pred_bool)
    if not gt_b.any() and not pred_b.any():
        return 1.0
    if not gt_b.any() or not pred_b.any():
        return 0.0
    gt_match = gt_b & dilate_binary(pred_b, tolerance_px)
    pred_match = pred_b & dilate_binary(gt_b, tolerance_px)
    precision = pred_match.sum() / (pred_b.sum() + EPS)
    recall = gt_match.sum() / (gt_b.sum() + EPS)
    return float((2 * precision * recall) / (precision + recall + EPS))


def evaluate_all(boundary_tolerance_px: int = 2):
    per_image_rows = []
    per_class_counts = {c: {"tp": 0, "fp": 0, "fn": 0} for c in range(N_CLASSES)}
    per_class_cldice = {c: {"pred_hits": 0, "pred_sum": 0, "gt_hits": 0, "gt_sum": 0} for c in range(1, N_CLASSES)}
    fg_counts = {"tp": 0, "fp": 0, "fn": 0}
    boundary_scores = []
    cldice_scores = []

    for idx, item in enumerate(samples):
        _, gt, pred = load_sample(idx)
        fg_gt = gt > 0
        fg_pred = pred > 0
        tp, fp, fn = binary_counts(fg_gt, fg_pred)
        fg_counts["tp"] += tp; fg_counts["fp"] += fp; fg_counts["fn"] += fn
        fg_metrics = prf_from_counts(tp, fp, fn)
        bf1 = boundary_f1(fg_gt, fg_pred, tolerance_px=boundary_tolerance_px)
        cldice = cldice_score(fg_gt, fg_pred)
        boundary_scores.append(bf1)
        cldice_scores.append(cldice)
        per_image_rows.append({
            "case_id": item["case_id"],
            "dice_f1": fg_metrics["dice_f1"],
            "precision": fg_metrics["precision"],
            "recall_sensitivity": fg_metrics["recall_sensitivity"],
            "boundary_f1": bf1,
            "cldice": cldice,
        })
        for c in range(N_CLASSES):
            gt_c = gt == c
            pred_c = pred == c
            c_tp, c_fp, c_fn = binary_counts(gt_c, pred_c)
            per_class_counts[c]["tp"] += c_tp
            per_class_counts[c]["fp"] += c_fp
            per_class_counts[c]["fn"] += c_fn
            if c > 0:
                pred_hits, pred_sum, gt_hits, gt_sum = cldice_components(gt_c, pred_c)
                per_class_cldice[c]["pred_hits"] += pred_hits
                per_class_cldice[c]["pred_sum"] += pred_sum
                per_class_cldice[c]["gt_hits"] += gt_hits
                per_class_cldice[c]["gt_sum"] += gt_sum

    overall = prf_from_counts(fg_counts["tp"], fg_counts["fp"], fg_counts["fn"])
    overall["boundary_f1"] = float(np.mean(boundary_scores)) if boundary_scores else np.nan
    overall["cldice"] = float(np.mean(cldice_scores)) if cldice_scores else np.nan
    overall["n_images"] = len(samples)

    per_class_rows = []
    for c in range(N_CLASSES):
        counts = per_class_counts[c]
        metrics = prf_from_counts(counts["tp"], counts["fp"], counts["fn"])
        per_class_rows.append({
            "class_id": c,
            "class_name": CLASS_LABELS[c],
            "tp": counts["tp"],
            "fp": counts["fp"],
            "fn": counts["fn"],
            **metrics,
            "cldice": cldice_from_components(
                per_class_cldice[c]["pred_hits"],
                per_class_cldice[c]["pred_sum"],
                per_class_cldice[c]["gt_hits"],
                per_class_cldice[c]["gt_sum"],
            ) if c > 0 else np.nan,
        })

    return pd.DataFrame(per_image_rows), pd.DataFrame(per_class_rows), pd.DataFrame([overall])

per_image_metrics, per_class_metrics, overall_metrics = evaluate_all(boundary_tolerance_px=2)

print("Overall foreground metrics")
display(overall_metrics)
print("Per-class metrics")
display(per_class_metrics)
print("Per-image foreground metrics")
display(per_image_metrics)

per_image_metrics.to_csv(METRICS_DIR / f"{NET_NAME}_per_image_metrics.csv", index=False)
per_class_metrics.to_csv(METRICS_DIR / f"{NET_NAME}_per_class_metrics.csv", index=False)
overall_metrics.to_csv(METRICS_DIR / f"{NET_NAME}_overall_metrics.csv", index=False)
print("Saved metrics to", METRICS_DIR)

# %% [markdown]
# ## Metrics: Class Purity, Fragmentation, Anatomical Consistency
#
# Dice/precision/recall score pixel overlap but don't penalize a model for blending two
# vessel classes inside one connected blob, or for splitting a vessel into disconnected
# islands, or for producing anatomically impossible labels. ARCADE is a hard case study:
# RCA (right coronary tree) and LAD/LCX (left coronary tree) never co-occur in one image,
# and along any single physical vessel LAD/LCX can only change identity at a bifurcation
# -- it can never revert to a label it already left behind.
#
# `analysis/segmentation_topology.py` implements four diagnostics per case:
# - **Territory leakage**: fraction of predicted foreground in the anatomically wrong
#   coronary territory (RCA predicted in an LAD/LCX case, or vice versa).
# - **Component purity**: for each spatially-connected predicted blob, what fraction of
#   its pixels belong to the majority class. Low purity = classes blended within one
#   segment, which is what makes a prediction hard to post-process.
# - **Fragmentation**: predicted vs. ground-truth connected-component counts (island
#   count), plus a noise-island count for tiny (&lt;5px) specks.
# - **Branch consistency**: skeletonizes the predicted LAD+LCX mask and checks, along
#   every endpoint-to-endpoint path in the vessel tree, whether a class label reappears
#   after being superseded by the other class (the illegal LAD-&gt;LCX-&gt;LAD pattern).
#
# See `analysis/README.md` for the full metric reference and folder layout.

# %%
import importlib
importlib.reload(topo)  # picks up edits to segmentation_topology.py without a kernel restart

topology_rows = []
for idx, item in enumerate(samples):
    _, gt, pred = load_sample(idx)
    topology_rows.append(topo.evaluate_case(item["case_id"], gt, pred))

topology_metrics = pd.DataFrame(topology_rows)

lad_lcx = topology_metrics[topology_metrics["territory"] == "LAD_LCX"]
rca = topology_metrics[topology_metrics["territory"] == "RCA"]
branch_valid = topology_metrics[topology_metrics["branch_n_paths"] > 0]

topology_summary = pd.DataFrame([{
    "model": NET_NAME,
    "n_cases": len(topology_metrics),
    "territory_leakage_rate_mean": topology_metrics["territory_leakage_rate"].mean(),
    "territory_leakage_rate_lad_lcx": lad_lcx["territory_leakage_rate"].mean() if len(lad_lcx) else np.nan,
    "territory_leakage_rate_rca": rca["territory_leakage_rate"].mean() if len(rca) else np.nan,
    "cases_with_leakage": int((topology_metrics["leaked_px"] > 0).sum()),
    "mean_component_purity": topology_metrics["mean_purity"].mean(),
    "area_weighted_purity": topology_metrics["area_weighted_purity"].mean(),
    "cases_with_mixed_component": int((topology_metrics["n_mixed_components"] > 0).sum()),
    "mean_pred_components": topology_metrics["pred_components"].mean(),
    "mean_gt_components": topology_metrics["gt_components"].mean(),
    "mean_component_ratio": topology_metrics["component_ratio"].replace([np.inf, -np.inf], np.nan).mean(),
    "mean_noise_islands": topology_metrics["pred_noise_islands"].mean(),
    "n_cases_with_branch_paths": len(branch_valid),
    "branch_inconsistent_path_rate_mean": branch_valid["branch_inconsistent_path_rate"].mean() if len(branch_valid) else np.nan,
    "cases_with_branch_inconsistency": int((topology_metrics["branch_n_inconsistent_paths"] > 0).sum()),
}])

print("Topology / purity / anatomical-consistency summary")
display(topology_summary)
print("Per-case topology diagnostics (head)")
display(topology_metrics.head())

topology_metrics.to_csv(METRICS_DIR / f"{NET_NAME}_topology_metrics.csv", index=False)
topology_summary.to_csv(METRICS_DIR / f"{NET_NAME}_topology_summary.csv", index=False)
print("Saved topology diagnostics to", METRICS_DIR)
